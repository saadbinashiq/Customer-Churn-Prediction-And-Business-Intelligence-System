# %% [markdown]
# # 03_feature_engineering

# %%
import pandas as pd

df=pd.read_csv('../data/processed/customer_churn_processed.csv')
features=['Customer_Lifetime_Months','Average_Monthly_Spend','Support_Calls_Per_Month','Service_Count','Usage_Change_Percentage','Payment_Delay_Rate']
print(df[features].describe().T)
