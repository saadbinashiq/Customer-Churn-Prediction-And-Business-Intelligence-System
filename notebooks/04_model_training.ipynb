# %% [markdown]
# # 04_model_training

# %%
import subprocess, sys
result=subprocess.run([sys.executable,'../src/train_model.py'],capture_output=True,text=True)
print(result.stdout)
print(result.stderr)
